# %% [markdown]
# # Player to player contact image classification - training

# %%
import os
import torch
from torch import nn
import numpy as np
import torch.nn.functional as F
import time
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from tqdm.auto import tqdm
from torch.optim import Adam, lr_scheduler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from PIL import Image
from torchvision import datasets, transforms
import torchvision.models as models
from sklearn.metrics import matthews_corrcoef

# %% [markdown]
# ## Load Data

# %%
DATASET_DIR = "dataset"

# train labels
train_labels_df =  pd.read_csv(os.path.join(DATASET_DIR, "train_labels.csv"), 
                               parse_dates=["datetime"])

# contact reduced to p2p distance below threshold
train_contact_df_reduced = pd.read_csv(os.path.join(DATASET_DIR, "train_contact_df_reduced.csv"))

# contact image
contact_image_endzone_df = pd.read_csv(os.path.join(DATASET_DIR, "train_contact_image_endzone_df.csv"))

# %% [markdown]
# ## The PlayerContact dataset

# %% [markdown]
# ### Transform function
# It converts the PIL Image into a Tensor and normalizes it using the mean and std values from Imagenet

# %%
# transforms
IMAGE_SIZE = 224 # Image size of resize when applying transforms.
# data augmentation for train set
image_transform_train = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(degrees=(0, 45)),
        transforms.ColorJitter(brightness=.5, hue=.3),
        transforms.RandomPerspective(distortion_scale=0.6, p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # imagenet
])

image_transform_test = transforms.Compose([
        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # imagenet
])

# %% [markdown]
# ## The PlayerContact Dataset Class
# The PlayerContact dataset class takes the data from the folder and returns images

# %%
class PlayerContactDataset(Dataset):
    """
    PlayerContact dataset that returns an image and feature vector
    """
    def __init__(self, data_dir, contact_df, view, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.contact_df = contact_df.fillna(-1) # fill nan with -1 for feature vector
        self.view = view
        
    def __getitem__(self, idx):
        # get the row
        row = self.contact_df.iloc[idx] 
        # get the image
        img_path = os.path.join(self.data_dir, row['contact_id']+'_'+self.view+'.jpg')
        image = Image.open(img_path).convert('RGB')
        if (self.transform):
            image = self.transform(image)
        
        # get feature vector
        if row['nfl_player_id_2'] == -1:
            # if ground contact, retrieve only player 1 data and no p2p distance
            feature_cols = ['x_position_1', 'y_position_1', 'speed_1', 'distance_1', 
                            'direction_1', 'orientation_1', 'acceleration_1', 'sa_1']
        else:
            feature_cols = ['x_position_1', 'y_position_1', 'speed_1', 'distance_1', 
                            'direction_1', 'orientation_1', 'acceleration_1', 'sa_1',
                            'x_position_2', 'y_position_2', 'speed_2', 'distance_2', 
                            'direction_2', 'orientation_2', 'acceleration_2', 'sa_2',
                            'p2p_distance']
            
        feature = torch.tensor(row[feature_cols]).float()
        
        # get the class label
        label = torch.tensor(row['contact_truth'])
        
        return image, feature, label
    
    def __len__(self):
        return len(self.contact_df)

# %% [markdown]
# ### Prepare and split the data

# %%
# # we want a dataset with 25% of positive contacts and 75% of negative contacts

# # merge contact_df and contact_image_df
# train_df = train_contact_df_reduced.merge(contact_image_endzone_df, 
#                                  left_on=['contact_id'], 
#                                  right_on=['contact_id'], 
#                                  how='left').drop_duplicates()
# # use only the rows where the crop was generated
# train_df = train_df[train_df['crop_generated'] == True]
# # get the ground contacts
# train_df = train_df[train_df['nfl_player_id_2'] == -1]

# # get all positive contacts
# pos_df = train_df[train_df['contact_truth'] == 1]
# num_pos = len(pos_df)

# # retrieve a number of negative contacts = to 3 times the number of positive contacts
# neg_df = train_df[train_df['contact_truth'] == 0].sample(3*num_pos, random_state=42)
# # concatenate negative and positive contacts
# train_df = pd.concat([pos_df, neg_df])

# # train test split
# train_df, test_df = train_test_split(train_df, test_size=0.2, random_state=42)

# train_df

# %%
# merge contact_df and contact_image_df
train_df = train_contact_df_reduced.merge(contact_image_endzone_df, 
                                 left_on=['contact_id'], 
                                 right_on=['contact_id'], 
                                 how='left').drop_duplicates()
# use only the rows where the crop was generated
train_df = train_df[train_df['crop_generated'] == True]
# get only player to player contact, no ground
train_df = train_df[train_df['nfl_player_id_2'] != -1]

# split the dataset
train_df, test_df = train_test_split(train_df, test_size=0.2, random_state=42)

train_df
# Out:
#                           contact_id     game_play  step  nfl_player_id_1  \
# 24598   58180_000986_117_46113_46164  58180_000986   117            46113
# 388289   58403_001076_53_41436_42765  58403_001076    53            41436
# 585954   58551_003569_43_43045_53462  58551_003569    43            43045
# 133523   58217_002635_58_47848_52522  58217_002635    58            47848
# 485413   58516_003538_83_43351_43420  58516_003538    83            43351
# ...                              ...           ...   ...              ...
# 327683   58329_002938_57_32200_43075  58329_002938    57            32200
# 282907   58302_004013_36_42589_47865  58302_004013    36            42589
# 363735   58368_003163_53_46163_47973  58368_003163    53            46163
# 403554   58415_003155_89_41319_46527  58415_003155    89            41319
# 335865   58336_000203_16_43645_52505  58336_000203    16            43645
#
#         nfl_player_id_2  game_key  play_id                          datetime  \
# 24598             46164     58180      986  2020-09-13 21:03:15.500000+00:00
# 388289            42765     58403     1076  2020-12-27 21:48:03.100000+00:00
# 585954            53462     58551     3569  2021-10-01 03:18:58.800000+00:00
# 133523            52522     58217     2635         2020-10-04 18:57:09+00:00
# 485413            43420     58516     3538  2021-09-12 23:11:14.300000+00:00
# ...                 ...       ...      ...                               ...
# 327683            43075     58329     2938  2020-11-26 19:54:31.300000+00:00
# 282907            47865     58302     4013  2020-11-13 04:18:59.700000+00:00
# 363735            47973     58368     3163         2020-12-13 20:31:19+00:00
# 403554            46527     58415     3155  2021-01-03 20:31:47.200000+00:00
# 335865            52505     58336      203  2020-11-29 18:08:17.100000+00:00
#
#        team_1 position_1  ...  orientation_2  acceleration_2  sa_2  \
# 24598    home         WR  ...         357.55            0.77  0.21
# 388289   away          C  ...         338.51            0.36 -0.28
# 585954   home          G  ...          61.78            0.84 -0.84
# 133523   away         DE  ...         263.51            1.63 -0.77
# 485413   home         CB  ...         307.50            0.24  0.16
# ...       ...        ...  ...            ...             ...   ...
# 327683   home         RB  ...         206.95            1.23 -0.42
# 282907   home         TE  ...         338.19            1.36 -0.76
# 363735   home          G  ...         105.81            0.79 -0.56
# 403554   home         WR  ...         239.69            2.82 -1.91
# 335865   home         SS  ...         311.27            4.49  2.06
#
#         p2p_distance  contact_truth  contact  crop_generated  rewinded_frames  \
# 24598       0.844808              0        0            True              0.0
# 388289      1.480709              0        0            True              0.0
# 585954      1.941649              0        0            True              0.0
# 133523      1.253555              0        0            True              0.0
# 485413      1.880425              0        0            True              0.0
# ...              ...            ...      ...             ...              ...
# 327683      1.165590              1        1            True              0.0
# 282907      1.619660              0        0            True              0.0
# 363735      0.960052              0        0            True              0.0
# 403554      1.735569              0        0            True              0.0
# 335865      1.166619              1        1            True              0.0
#
#         miss_helmet_dets miss_player_dets
# 24598                1.0              1.0
# 388289               1.0              1.0
# 585954               1.0              1.0
# 133523               0.0              0.0
# 485413               0.0              0.0
# ...                  ...              ...
# 327683               0.0              0.0
# 282907               0.0              0.0
# 363735               0.0              0.0
# 403554               1.0              1.0
# 335865               0.0              0.0
#
# [189807 rows x 37 columns]

# %%
num_contacts = train_df['contact_truth'].sum()
print(f"There are {num_contacts} positive p2p contacts in the train set")
print(f"{num_contacts / len(train_df)*100:.2f}% of p2p contacts are positive on the train set")
# Out:
# There are 36787 positive p2p contacts in the train set
# 19.38% of p2p contacts are positive on the train set

# %% [markdown]
# ### Create instance of the dataset specific to player-player contact

# %%
DATA_PATH = os.path.join('dataset', 'train', 'crops')
# train
p2p_contact_dataset_train = PlayerContactDataset(DATA_PATH, train_df, 'Endzone', image_transform_train)
# test
p2p_contact_dataset_test = PlayerContactDataset(DATA_PATH, test_df, 'Endzone', image_transform_test)

# %% [markdown]
# ### Utils to show image from dataset

# %%
def inverse_normalize(tensor, mean, std):
    for channel_tensor, c_mean, c_std in zip(tensor, mean, std):
        channel_tensor.mul_(c_std).add_(c_mean)
        # The normalize code -> channel_tensor.sub_(c_mean).div_(c_std)
        
    return tensor

def tensor_to_image(tensor, is_normalized=True):
    img = tensor
    if is_normalized:
        img = inverse_normalize(img, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
    img = np.array(img).transpose(1, 2, 0)
    img = Image.fromarray((img*255).astype(np.uint8))
    
    return img

# %%
tensor_to_image(p2p_contact_dataset_train[700][0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### Data Loaders

# %%
BATCH_SIZE = 32

loader_train = DataLoader(p2p_contact_dataset_train,
                         batch_size=BATCH_SIZE,
                         shuffle=True, 
                         num_workers=0,
                         drop_last=True) # drop last batch with size < 8 so that the batchnorm layers dont fail

loader_test = DataLoader(p2p_contact_dataset_test,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=0,
                         drop_last=False)

# %%
# get one batch
images, features, labels = next(iter(loader_train))
# check the batch size
print(f'Batch size: {len(images)}')
print(f'Image shape: {images.shape}')
print(f'feature shape: {features.shape}')
print(f'labels shape: {labels.shape}')
# Out:
# Batch size: 32
# Image shape: torch.Size([32, 3, 224, 224])
# feature shape: torch.Size([32, 17])
# labels shape: torch.Size([32])

# %% [markdown]
# ## Load the efficientnet model with no classification head

# %%
def get_efficientnet_model(pretrained=True, fine_tune=True):
    """
    Returns en efficientnetB0 model that retturns the flattenned feature
    """
    model = models.efficientnet_b0(pretrained=pretrained)
    if fine_tune:
        for params in model.parameters():
            params.requires_grad = True
    elif not fine_tune:
        for params in model.parameters():
            params.requires_grad = False
            
    # Replace the final classification head with a flatten layer
    model.classifier = nn.Flatten()
            
    return model

# %%
cosa = get_efficientnet_model(pretrained=True, fine_tune=True)
# Out:
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
cosa
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Flatten(start_dim=1, end_dim=-1)
# )

# %%
dict(cosa.named_modules())
# Out:
# {'': EfficientNet(
#    (features): Sequential(
#      (0): Conv2dNormActivation(
#        (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (1): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#              (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (2): Conv2dNormActivation(
#              (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#        )
#      )
#      (2): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#              (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#        )
#        (1): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#              (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#        )
#      )
#      (3): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#              (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#        )
#        (1): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#              (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#        )
#      )
#      (4): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#              (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#        )
#        (1): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#        )
#        (2): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#        )
#      )
#      (5): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#              (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#        )
#        (1): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#        )
#        (2): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#        )
#      )
#      (6): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#              (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#        )
#        (1): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#        )
#        (2): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#        )
#        (3): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#        )
#      )
#      (7): Sequential(
#        (0): MBConv(
#          (block): Sequential(
#            (0): Conv2dNormActivation(
#              (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (1): Conv2dNormActivation(
#              (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#              (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#              (2): SiLU(inplace=True)
#            )
#            (2): SqueezeExcitation(
#              (avgpool): AdaptiveAvgPool2d(output_size=1)
#              (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#              (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#              (activation): SiLU(inplace=True)
#              (scale_activation): Sigmoid()
#            )
#            (3): Conv2dNormActivation(
#              (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#        )
#      )
#      (8): Conv2dNormActivation(
#        (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#    )
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (classifier): Flatten(start_dim=1, end_dim=-1)
#  ),
#  'features': Sequential(
#    (0): Conv2dNormActivation(
#      (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#      (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (1): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#            (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (2): Conv2dNormActivation(
#            (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#      )
#    )
#    (2): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#            (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#      )
#      (1): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#            (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#      )
#    )
#    (3): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#            (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#      )
#      (1): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#            (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#      )
#    )
#    (4): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#            (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#      )
#      (1): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#      )
#      (2): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#      )
#    )
#    (5): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#            (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#      )
#      (1): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#      )
#      (2): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#      )
#    )
#    (6): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#            (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#      )
#      (1): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#      )
#      (2): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#      )
#      (3): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#      )
#    )
#    (7): Sequential(
#      (0): MBConv(
#        (block): Sequential(
#          (0): Conv2dNormActivation(
#            (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (1): Conv2dNormActivation(
#            (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#            (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (2): SiLU(inplace=True)
#          )
#          (2): SqueezeExcitation(
#            (avgpool): AdaptiveAvgPool2d(output_size=1)
#            (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#            (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#            (activation): SiLU(inplace=True)
#            (scale_activation): Sigmoid()
#          )
#          (3): Conv2dNormActivation(
#            (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          )
#        )
#        (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#      )
#    )
#    (8): Conv2dNormActivation(
#      (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#  ),
#  'features.0': Conv2dNormActivation(
#    (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#    (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.0.0': Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False),
#  'features.0.1': BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.0.2': SiLU(inplace=True),
#  'features.1': Sequential(
#    (0): MBConv(
#      (block): Sequential(
#        (0): Conv2dNormActivation(
#          (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#          (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (1): SqueezeExcitation(
#          (avgpool): AdaptiveAvgPool2d(output_size=1)
#          (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#          (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#          (activation): SiLU(inplace=True)
#          (scale_activation): Sigmoid()
#        )
#        (2): Conv2dNormActivation(
#          (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#    )
#  ),
#  'features.1.0': MBConv(
#    (block): Sequential(
#      (0): Conv2dNormActivation(
#        (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (1): SqueezeExcitation(
#        (avgpool): AdaptiveAvgPool2d(output_size=1)
#        (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#        (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#        (activation): SiLU(inplace=True)
#        (scale_activation): Sigmoid()
#      )
#      (2): Conv2dNormActivation(
#        (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#  ),
#  'features.1.0.block': Sequential(
#    (0): Conv2dNormActivation(
#      (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#      (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (1): SqueezeExcitation(
#      (avgpool): AdaptiveAvgPool2d(output_size=1)
#      (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#      (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#      (activation): SiLU(inplace=True)
#      (scale_activation): Sigmoid()
#    )
#    (2): Conv2dNormActivation(
#      (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  'features.1.0.block.0': Conv2dNormActivation(
#    (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#    (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.1.0.block.0.0': Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False),
#  'features.1.0.block.0.1': BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.1.0.block.0.2': SiLU(inplace=True),
#  'features.1.0.block.1': SqueezeExcitation(
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#    (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#    (activation): SiLU(inplace=True)
#    (scale_activation): Sigmoid()
#  ),
#  'features.1.0.block.1.avgpool': AdaptiveAvgPool2d(output_size=1),
#  'features.1.0.block.1.fc1': Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1)),
#  'features.1.0.block.1.fc2': Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1)),
#  'features.1.0.block.1.activation': SiLU(inplace=True),
#  'features.1.0.block.1.scale_activation': Sigmoid(),
#  'features.1.0.block.2': Conv2dNormActivation(
#    (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#  ),
#  'features.1.0.block.2.0': Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.1.0.block.2.1': BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.1.0.stochastic_depth': StochasticDepth(p=0.0, mode=row),
#  'features.2': Sequential(
#    (0): MBConv(
#      (block): Sequential(
#        (0): Conv2dNormActivation(
#          (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (1): Conv2dNormActivation(
#          (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#          (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (2): SqueezeExcitation(
#          (avgpool): AdaptiveAvgPool2d(output_size=1)
#          (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#          (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#          (activation): SiLU(inplace=True)
#          (scale_activation): Sigmoid()
#        )
#        (3): Conv2dNormActivation(
#          (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#    )
#    (1): MBConv(
#      (block): Sequential(
#        (0): Conv2dNormActivation(
#          (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (1): Conv2dNormActivation(
#          (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#          (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (2): SqueezeExcitation(
#          (avgpool): AdaptiveAvgPool2d(output_size=1)
#          (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#          (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#          (activation): SiLU(inplace=True)
#          (scale_activation): Sigmoid()
#        )
#        (3): Conv2dNormActivation(
#          (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#    )
#  ),
#  'features.2.0': MBConv(
#    (block): Sequential(
#      (0): Conv2dNormActivation(
# ...
#  'features.6.1.block.1.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.1.block.1.2': SiLU(inplace=True),
#  'features.6.1.block.2': SqueezeExcitation(
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#    (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#    (activation): SiLU(inplace=True)
#    (scale_activation): Sigmoid()
#  ),
#  'features.6.1.block.2.avgpool': AdaptiveAvgPool2d(output_size=1),
#  'features.6.1.block.2.fc1': Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.1.block.2.fc2': Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.1.block.2.activation': SiLU(inplace=True),
#  'features.6.1.block.2.scale_activation': Sigmoid(),
#  'features.6.1.block.3': Conv2dNormActivation(
#    (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#  ),
#  'features.6.1.block.3.0': Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.6.1.block.3.1': BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.1.stochastic_depth': StochasticDepth(p=0.15000000000000002, mode=row),
#  'features.6.2': MBConv(
#    (block): Sequential(
#      (0): Conv2dNormActivation(
#        (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (1): Conv2dNormActivation(
#        (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (2): SqueezeExcitation(
#        (avgpool): AdaptiveAvgPool2d(output_size=1)
#        (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#        (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#        (activation): SiLU(inplace=True)
#        (scale_activation): Sigmoid()
#      )
#      (3): Conv2dNormActivation(
#        (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#  ),
#  'features.6.2.block': Sequential(
#    (0): Conv2dNormActivation(
#      (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (1): Conv2dNormActivation(
#      (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (2): SqueezeExcitation(
#      (avgpool): AdaptiveAvgPool2d(output_size=1)
#      (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#      (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#      (activation): SiLU(inplace=True)
#      (scale_activation): Sigmoid()
#    )
#    (3): Conv2dNormActivation(
#      (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  'features.6.2.block.0': Conv2dNormActivation(
#    (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.6.2.block.0.0': Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.6.2.block.0.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.2.block.0.2': SiLU(inplace=True),
#  'features.6.2.block.1': Conv2dNormActivation(
#    (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.6.2.block.1.0': Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False),
#  'features.6.2.block.1.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.2.block.1.2': SiLU(inplace=True),
#  'features.6.2.block.2': SqueezeExcitation(
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#    (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#    (activation): SiLU(inplace=True)
#    (scale_activation): Sigmoid()
#  ),
#  'features.6.2.block.2.avgpool': AdaptiveAvgPool2d(output_size=1),
#  'features.6.2.block.2.fc1': Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.2.block.2.fc2': Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.2.block.2.activation': SiLU(inplace=True),
#  'features.6.2.block.2.scale_activation': Sigmoid(),
#  'features.6.2.block.3': Conv2dNormActivation(
#    (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#  ),
#  'features.6.2.block.3.0': Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.6.2.block.3.1': BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.2.stochastic_depth': StochasticDepth(p=0.1625, mode=row),
#  'features.6.3': MBConv(
#    (block): Sequential(
#      (0): Conv2dNormActivation(
#        (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (1): Conv2dNormActivation(
#        (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (2): SqueezeExcitation(
#        (avgpool): AdaptiveAvgPool2d(output_size=1)
#        (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#        (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#        (activation): SiLU(inplace=True)
#        (scale_activation): Sigmoid()
#      )
#      (3): Conv2dNormActivation(
#        (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#  ),
#  'features.6.3.block': Sequential(
#    (0): Conv2dNormActivation(
#      (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (1): Conv2dNormActivation(
#      (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (2): SqueezeExcitation(
#      (avgpool): AdaptiveAvgPool2d(output_size=1)
#      (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#      (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#      (activation): SiLU(inplace=True)
#      (scale_activation): Sigmoid()
#    )
#    (3): Conv2dNormActivation(
#      (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  'features.6.3.block.0': Conv2dNormActivation(
#    (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.6.3.block.0.0': Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.6.3.block.0.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.3.block.0.2': SiLU(inplace=True),
#  'features.6.3.block.1': Conv2dNormActivation(
#    (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.6.3.block.1.0': Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False),
#  'features.6.3.block.1.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.3.block.1.2': SiLU(inplace=True),
#  'features.6.3.block.2': SqueezeExcitation(
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#    (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#    (activation): SiLU(inplace=True)
#    (scale_activation): Sigmoid()
#  ),
#  'features.6.3.block.2.avgpool': AdaptiveAvgPool2d(output_size=1),
#  'features.6.3.block.2.fc1': Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.3.block.2.fc2': Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)),
#  'features.6.3.block.2.activation': SiLU(inplace=True),
#  'features.6.3.block.2.scale_activation': Sigmoid(),
#  'features.6.3.block.3': Conv2dNormActivation(
#    (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#  ),
#  'features.6.3.block.3.0': Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.6.3.block.3.1': BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.6.3.stochastic_depth': StochasticDepth(p=0.17500000000000002, mode=row),
#  'features.7': Sequential(
#    (0): MBConv(
#      (block): Sequential(
#        (0): Conv2dNormActivation(
#          (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (1): Conv2dNormActivation(
#          (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#          (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): SiLU(inplace=True)
#        )
#        (2): SqueezeExcitation(
#          (avgpool): AdaptiveAvgPool2d(output_size=1)
#          (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#          (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#          (activation): SiLU(inplace=True)
#          (scale_activation): Sigmoid()
#        )
#        (3): Conv2dNormActivation(
#          (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#    )
#  ),
#  'features.7.0': MBConv(
#    (block): Sequential(
#      (0): Conv2dNormActivation(
#        (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (1): Conv2dNormActivation(
#        (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#        (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): SiLU(inplace=True)
#      )
#      (2): SqueezeExcitation(
#        (avgpool): AdaptiveAvgPool2d(output_size=1)
#        (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#        (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#        (activation): SiLU(inplace=True)
#        (scale_activation): Sigmoid()
#      )
#      (3): Conv2dNormActivation(
#        (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      )
#    )
#    (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#  ),
#  'features.7.0.block': Sequential(
#    (0): Conv2dNormActivation(
#      (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (1): Conv2dNormActivation(
#      (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#      (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): SiLU(inplace=True)
#    )
#    (2): SqueezeExcitation(
#      (avgpool): AdaptiveAvgPool2d(output_size=1)
#      (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#      (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#      (activation): SiLU(inplace=True)
#      (scale_activation): Sigmoid()
#    )
#    (3): Conv2dNormActivation(
#      (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    )
#  ),
#  'features.7.0.block.0': Conv2dNormActivation(
#    (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.7.0.block.0.0': Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.7.0.block.0.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.7.0.block.0.2': SiLU(inplace=True),
#  'features.7.0.block.1': Conv2dNormActivation(
#    (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#    (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.7.0.block.1.0': Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False),
#  'features.7.0.block.1.1': BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.7.0.block.1.2': SiLU(inplace=True),
#  'features.7.0.block.2': SqueezeExcitation(
#    (avgpool): AdaptiveAvgPool2d(output_size=1)
#    (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#    (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#    (activation): SiLU(inplace=True)
#    (scale_activation): Sigmoid()
#  ),
#  'features.7.0.block.2.avgpool': AdaptiveAvgPool2d(output_size=1),
#  'features.7.0.block.2.fc1': Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)),
#  'features.7.0.block.2.fc2': Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)),
#  'features.7.0.block.2.activation': SiLU(inplace=True),
#  'features.7.0.block.2.scale_activation': Sigmoid(),
#  'features.7.0.block.3': Conv2dNormActivation(
#    (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#  ),
#  'features.7.0.block.3.0': Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.7.0.block.3.1': BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.7.0.stochastic_depth': StochasticDepth(p=0.1875, mode=row),
#  'features.8': Conv2dNormActivation(
#    (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (2): SiLU(inplace=True)
#  ),
#  'features.8.0': Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False),
#  'features.8.1': BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'features.8.2': SiLU(inplace=True),
#  'avgpool': AdaptiveAvgPool2d(output_size=1),
#  'classifier': Flatten(start_dim=1, end_dim=-1)}

# %%
lola = 'cosa'
'co' in lola
# Out:
# True

# %%
for i, (name, params) in enumerate(cosa.named_parameters()):
    print(f"{i}  layer: {name} shape: {params.shape} requires_grad: {params.requires_grad}")
# Out:
# 0  layer: features.0.0.weight shape: torch.Size([32, 3, 3, 3]) requires_grad: True
# 1  layer: features.0.1.weight shape: torch.Size([32]) requires_grad: True
# 2  layer: features.0.1.bias shape: torch.Size([32]) requires_grad: True
# 3  layer: features.1.0.block.0.0.weight shape: torch.Size([32, 1, 3, 3]) requires_grad: True
# 4  layer: features.1.0.block.0.1.weight shape: torch.Size([32]) requires_grad: True
# 5  layer: features.1.0.block.0.1.bias shape: torch.Size([32]) requires_grad: True
# 6  layer: features.1.0.block.1.fc1.weight shape: torch.Size([8, 32, 1, 1]) requires_grad: True
# 7  layer: features.1.0.block.1.fc1.bias shape: torch.Size([8]) requires_grad: True
# 8  layer: features.1.0.block.1.fc2.weight shape: torch.Size([32, 8, 1, 1]) requires_grad: True
# 9  layer: features.1.0.block.1.fc2.bias shape: torch.Size([32]) requires_grad: True
# 10  layer: features.1.0.block.2.0.weight shape: torch.Size([16, 32, 1, 1]) requires_grad: True
# 11  layer: features.1.0.block.2.1.weight shape: torch.Size([16]) requires_grad: True
# 12  layer: features.1.0.block.2.1.bias shape: torch.Size([16]) requires_grad: True
# 13  layer: features.2.0.block.0.0.weight shape: torch.Size([96, 16, 1, 1]) requires_grad: True
# 14  layer: features.2.0.block.0.1.weight shape: torch.Size([96]) requires_grad: True
# 15  layer: features.2.0.block.0.1.bias shape: torch.Size([96]) requires_grad: True
# 16  layer: features.2.0.block.1.0.weight shape: torch.Size([96, 1, 3, 3]) requires_grad: True
# 17  layer: features.2.0.block.1.1.weight shape: torch.Size([96]) requires_grad: True
# 18  layer: features.2.0.block.1.1.bias shape: torch.Size([96]) requires_grad: True
# 19  layer: features.2.0.block.2.fc1.weight shape: torch.Size([4, 96, 1, 1]) requires_grad: True
# 20  layer: features.2.0.block.2.fc1.bias shape: torch.Size([4]) requires_grad: True
# 21  layer: features.2.0.block.2.fc2.weight shape: torch.Size([96, 4, 1, 1]) requires_grad: True
# 22  layer: features.2.0.block.2.fc2.bias shape: torch.Size([96]) requires_grad: True
# 23  layer: features.2.0.block.3.0.weight shape: torch.Size([24, 96, 1, 1]) requires_grad: True
# 24  layer: features.2.0.block.3.1.weight shape: torch.Size([24]) requires_grad: True
# 25  layer: features.2.0.block.3.1.bias shape: torch.Size([24]) requires_grad: True
# 26  layer: features.2.1.block.0.0.weight shape: torch.Size([144, 24, 1, 1]) requires_grad: True
# 27  layer: features.2.1.block.0.1.weight shape: torch.Size([144]) requires_grad: True
# 28  layer: features.2.1.block.0.1.bias shape: torch.Size([144]) requires_grad: True
# 29  layer: features.2.1.block.1.0.weight shape: torch.Size([144, 1, 3, 3]) requires_grad: True
# 30  layer: features.2.1.block.1.1.weight shape: torch.Size([144]) requires_grad: True
# 31  layer: features.2.1.block.1.1.bias shape: torch.Size([144]) requires_grad: True
# 32  layer: features.2.1.block.2.fc1.weight shape: torch.Size([6, 144, 1, 1]) requires_grad: True
# 33  layer: features.2.1.block.2.fc1.bias shape: torch.Size([6]) requires_grad: True
# 34  layer: features.2.1.block.2.fc2.weight shape: torch.Size([144, 6, 1, 1]) requires_grad: True
# 35  layer: features.2.1.block.2.fc2.bias shape: torch.Size([144]) requires_grad: True
# 36  layer: features.2.1.block.3.0.weight shape: torch.Size([24, 144, 1, 1]) requires_grad: True
# 37  layer: features.2.1.block.3.1.weight shape: torch.Size([24]) requires_grad: True
# 38  layer: features.2.1.block.3.1.bias shape: torch.Size([24]) requires_grad: True
# 39  layer: features.3.0.block.0.0.weight shape: torch.Size([144, 24, 1, 1]) requires_grad: True
# 40  layer: features.3.0.block.0.1.weight shape: torch.Size([144]) requires_grad: True
# 41  layer: features.3.0.block.0.1.bias shape: torch.Size([144]) requires_grad: True
# 42  layer: features.3.0.block.1.0.weight shape: torch.Size([144, 1, 5, 5]) requires_grad: True
# 43  layer: features.3.0.block.1.1.weight shape: torch.Size([144]) requires_grad: True
# 44  layer: features.3.0.block.1.1.bias shape: torch.Size([144]) requires_grad: True
# 45  layer: features.3.0.block.2.fc1.weight shape: torch.Size([6, 144, 1, 1]) requires_grad: True
# 46  layer: features.3.0.block.2.fc1.bias shape: torch.Size([6]) requires_grad: True
# 47  layer: features.3.0.block.2.fc2.weight shape: torch.Size([144, 6, 1, 1]) requires_grad: True
# 48  layer: features.3.0.block.2.fc2.bias shape: torch.Size([144]) requires_grad: True
# 49  layer: features.3.0.block.3.0.weight shape: torch.Size([40, 144, 1, 1]) requires_grad: True
# 50  layer: features.3.0.block.3.1.weight shape: torch.Size([40]) requires_grad: True
# 51  layer: features.3.0.block.3.1.bias shape: torch.Size([40]) requires_grad: True
# 52  layer: features.3.1.block.0.0.weight shape: torch.Size([240, 40, 1, 1]) requires_grad: True
# 53  layer: features.3.1.block.0.1.weight shape: torch.Size([240]) requires_grad: True
# 54  layer: features.3.1.block.0.1.bias shape: torch.Size([240]) requires_grad: True
# 55  layer: features.3.1.block.1.0.weight shape: torch.Size([240, 1, 5, 5]) requires_grad: True
# 56  layer: features.3.1.block.1.1.weight shape: torch.Size([240]) requires_grad: True
# 57  layer: features.3.1.block.1.1.bias shape: torch.Size([240]) requires_grad: True
# 58  layer: features.3.1.block.2.fc1.weight shape: torch.Size([10, 240, 1, 1]) requires_grad: True
# 59  layer: features.3.1.block.2.fc1.bias shape: torch.Size([10]) requires_grad: True
# 60  layer: features.3.1.block.2.fc2.weight shape: torch.Size([240, 10, 1, 1]) requires_grad: True
# 61  layer: features.3.1.block.2.fc2.bias shape: torch.Size([240]) requires_grad: True
# 62  layer: features.3.1.block.3.0.weight shape: torch.Size([40, 240, 1, 1]) requires_grad: True
# 63  layer: features.3.1.block.3.1.weight shape: torch.Size([40]) requires_grad: True
# 64  layer: features.3.1.block.3.1.bias shape: torch.Size([40]) requires_grad: True
# 65  layer: features.4.0.block.0.0.weight shape: torch.Size([240, 40, 1, 1]) requires_grad: True
# 66  layer: features.4.0.block.0.1.weight shape: torch.Size([240]) requires_grad: True
# 67  layer: features.4.0.block.0.1.bias shape: torch.Size([240]) requires_grad: True
# 68  layer: features.4.0.block.1.0.weight shape: torch.Size([240, 1, 3, 3]) requires_grad: True
# 69  layer: features.4.0.block.1.1.weight shape: torch.Size([240]) requires_grad: True
# 70  layer: features.4.0.block.1.1.bias shape: torch.Size([240]) requires_grad: True
# 71  layer: features.4.0.block.2.fc1.weight shape: torch.Size([10, 240, 1, 1]) requires_grad: True
# 72  layer: features.4.0.block.2.fc1.bias shape: torch.Size([10]) requires_grad: True
# 73  layer: features.4.0.block.2.fc2.weight shape: torch.Size([240, 10, 1, 1]) requires_grad: True
# 74  layer: features.4.0.block.2.fc2.bias shape: torch.Size([240]) requires_grad: True
# 75  layer: features.4.0.block.3.0.weight shape: torch.Size([80, 240, 1, 1]) requires_grad: True
# 76  layer: features.4.0.block.3.1.weight shape: torch.Size([80]) requires_grad: True
# 77  layer: features.4.0.block.3.1.bias shape: torch.Size([80]) requires_grad: True
# 78  layer: features.4.1.block.0.0.weight shape: torch.Size([480, 80, 1, 1]) requires_grad: True
# 79  layer: features.4.1.block.0.1.weight shape: torch.Size([480]) requires_grad: True
# 80  layer: features.4.1.block.0.1.bias shape: torch.Size([480]) requires_grad: True
# 81  layer: features.4.1.block.1.0.weight shape: torch.Size([480, 1, 3, 3]) requires_grad: True
# 82  layer: features.4.1.block.1.1.weight shape: torch.Size([480]) requires_grad: True
# 83  layer: features.4.1.block.1.1.bias shape: torch.Size([480]) requires_grad: True
# 84  layer: features.4.1.block.2.fc1.weight shape: torch.Size([20, 480, 1, 1]) requires_grad: True
# 85  layer: features.4.1.block.2.fc1.bias shape: torch.Size([20]) requires_grad: True
# 86  layer: features.4.1.block.2.fc2.weight shape: torch.Size([480, 20, 1, 1]) requires_grad: True
# 87  layer: features.4.1.block.2.fc2.bias shape: torch.Size([480]) requires_grad: True
# 88  layer: features.4.1.block.3.0.weight shape: torch.Size([80, 480, 1, 1]) requires_grad: True
# 89  layer: features.4.1.block.3.1.weight shape: torch.Size([80]) requires_grad: True
# 90  layer: features.4.1.block.3.1.bias shape: torch.Size([80]) requires_grad: True
# 91  layer: features.4.2.block.0.0.weight shape: torch.Size([480, 80, 1, 1]) requires_grad: True
# 92  layer: features.4.2.block.0.1.weight shape: torch.Size([480]) requires_grad: True
# 93  layer: features.4.2.block.0.1.bias shape: torch.Size([480]) requires_grad: True
# 94  layer: features.4.2.block.1.0.weight shape: torch.Size([480, 1, 3, 3]) requires_grad: True
# 95  layer: features.4.2.block.1.1.weight shape: torch.Size([480]) requires_grad: True
# 96  layer: features.4.2.block.1.1.bias shape: torch.Size([480]) requires_grad: True
# 97  layer: features.4.2.block.2.fc1.weight shape: torch.Size([20, 480, 1, 1]) requires_grad: True
# 98  layer: features.4.2.block.2.fc1.bias shape: torch.Size([20]) requires_grad: True
# 99  layer: features.4.2.block.2.fc2.weight shape: torch.Size([480, 20, 1, 1]) requires_grad: True
# 100  layer: features.4.2.block.2.fc2.bias shape: torch.Size([480]) requires_grad: True
# 101  layer: features.4.2.block.3.0.weight shape: torch.Size([80, 480, 1, 1]) requires_grad: True
# 102  layer: features.4.2.block.3.1.weight shape: torch.Size([80]) requires_grad: True
# 103  layer: features.4.2.block.3.1.bias shape: torch.Size([80]) requires_grad: True
# 104  layer: features.5.0.block.0.0.weight shape: torch.Size([480, 80, 1, 1]) requires_grad: True
# 105  layer: features.5.0.block.0.1.weight shape: torch.Size([480]) requires_grad: True
# 106  layer: features.5.0.block.0.1.bias shape: torch.Size([480]) requires_grad: True
# 107  layer: features.5.0.block.1.0.weight shape: torch.Size([480, 1, 5, 5]) requires_grad: True
# 108  layer: features.5.0.block.1.1.weight shape: torch.Size([480]) requires_grad: True
# 109  layer: features.5.0.block.1.1.bias shape: torch.Size([480]) requires_grad: True
# 110  layer: features.5.0.block.2.fc1.weight shape: torch.Size([20, 480, 1, 1]) requires_grad: True
# 111  layer: features.5.0.block.2.fc1.bias shape: torch.Size([20]) requires_grad: True
# 112  layer: features.5.0.block.2.fc2.weight shape: torch.Size([480, 20, 1, 1]) requires_grad: True
# 113  layer: features.5.0.block.2.fc2.bias shape: torch.Size([480]) requires_grad: True
# 114  layer: features.5.0.block.3.0.weight shape: torch.Size([112, 480, 1, 1]) requires_grad: True
# 115  layer: features.5.0.block.3.1.weight shape: torch.Size([112]) requires_grad: True
# 116  layer: features.5.0.block.3.1.bias shape: torch.Size([112]) requires_grad: True
# 117  layer: features.5.1.block.0.0.weight shape: torch.Size([672, 112, 1, 1]) requires_grad: True
# 118  layer: features.5.1.block.0.1.weight shape: torch.Size([672]) requires_grad: True
# 119  layer: features.5.1.block.0.1.bias shape: torch.Size([672]) requires_grad: True
# 120  layer: features.5.1.block.1.0.weight shape: torch.Size([672, 1, 5, 5]) requires_grad: True
# 121  layer: features.5.1.block.1.1.weight shape: torch.Size([672]) requires_grad: True
# 122  layer: features.5.1.block.1.1.bias shape: torch.Size([672]) requires_grad: True
# 123  layer: features.5.1.block.2.fc1.weight shape: torch.Size([28, 672, 1, 1]) requires_grad: True
# 124  layer: features.5.1.block.2.fc1.bias shape: torch.Size([28]) requires_grad: True
# 125  layer: features.5.1.block.2.fc2.weight shape: torch.Size([672, 28, 1, 1]) requires_grad: True
# 126  layer: features.5.1.block.2.fc2.bias shape: torch.Size([672]) requires_grad: True
# 127  layer: features.5.1.block.3.0.weight shape: torch.Size([112, 672, 1, 1]) requires_grad: True
# 128  layer: features.5.1.block.3.1.weight shape: torch.Size([112]) requires_grad: True
# 129  layer: features.5.1.block.3.1.bias shape: torch.Size([112]) requires_grad: True
# 130  layer: features.5.2.block.0.0.weight shape: torch.Size([672, 112, 1, 1]) requires_grad: True
# 131  layer: features.5.2.block.0.1.weight shape: torch.Size([672]) requires_grad: True
# 132  layer: features.5.2.block.0.1.bias shape: torch.Size([672]) requires_grad: True
# 133  layer: features.5.2.block.1.0.weight shape: torch.Size([672, 1, 5, 5]) requires_grad: True
# 134  layer: features.5.2.block.1.1.weight shape: torch.Size([672]) requires_grad: True
# 135  layer: features.5.2.block.1.1.bias shape: torch.Size([672]) requires_grad: True
# 136  layer: features.5.2.block.2.fc1.weight shape: torch.Size([28, 672, 1, 1]) requires_grad: True
# 137  layer: features.5.2.block.2.fc1.bias shape: torch.Size([28]) requires_grad: True
# 138  layer: features.5.2.block.2.fc2.weight shape: torch.Size([672, 28, 1, 1]) requires_grad: True
# 139  layer: features.5.2.block.2.fc2.bias shape: torch.Size([672]) requires_grad: True
# 140  layer: features.5.2.block.3.0.weight shape: torch.Size([112, 672, 1, 1]) requires_grad: True
# 141  layer: features.5.2.block.3.1.weight shape: torch.Size([112]) requires_grad: True
# 142  layer: features.5.2.block.3.1.bias shape: torch.Size([112]) requires_grad: True
# 143  layer: features.6.0.block.0.0.weight shape: torch.Size([672, 112, 1, 1]) requires_grad: True
# 144  layer: features.6.0.block.0.1.weight shape: torch.Size([672]) requires_grad: True
# 145  layer: features.6.0.block.0.1.bias shape: torch.Size([672]) requires_grad: True
# 146  layer: features.6.0.block.1.0.weight shape: torch.Size([672, 1, 5, 5]) requires_grad: True
# 147  layer: features.6.0.block.1.1.weight shape: torch.Size([672]) requires_grad: True
# 148  layer: features.6.0.block.1.1.bias shape: torch.Size([672]) requires_grad: True
# 149  layer: features.6.0.block.2.fc1.weight shape: torch.Size([28, 672, 1, 1]) requires_grad: True
# 150  layer: features.6.0.block.2.fc1.bias shape: torch.Size([28]) requires_grad: True
# 151  layer: features.6.0.block.2.fc2.weight shape: torch.Size([672, 28, 1, 1]) requires_grad: True
# 152  layer: features.6.0.block.2.fc2.bias shape: torch.Size([672]) requires_grad: True
# 153  layer: features.6.0.block.3.0.weight shape: torch.Size([192, 672, 1, 1]) requires_grad: True
# 154  layer: features.6.0.block.3.1.weight shape: torch.Size([192]) requires_grad: True
# 155  layer: features.6.0.block.3.1.bias shape: torch.Size([192]) requires_grad: True
# 156  layer: features.6.1.block.0.0.weight shape: torch.Size([1152, 192, 1, 1]) requires_grad: True
# 157  layer: features.6.1.block.0.1.weight shape: torch.Size([1152]) requires_grad: True
# 158  layer: features.6.1.block.0.1.bias shape: torch.Size([1152]) requires_grad: True
# 159  layer: features.6.1.block.1.0.weight shape: torch.Size([1152, 1, 5, 5]) requires_grad: True
# 160  layer: features.6.1.block.1.1.weight shape: torch.Size([1152]) requires_grad: True
# 161  layer: features.6.1.block.1.1.bias shape: torch.Size([1152]) requires_grad: True
# 162  layer: features.6.1.block.2.fc1.weight shape: torch.Size([48, 1152, 1, 1]) requires_grad: True
# 163  layer: features.6.1.block.2.fc1.bias shape: torch.Size([48]) requires_grad: True
# 164  layer: features.6.1.block.2.fc2.weight shape: torch.Size([1152, 48, 1, 1]) requires_grad: True
# 165  layer: features.6.1.block.2.fc2.bias shape: torch.Size([1152]) requires_grad: True
# 166  layer: features.6.1.block.3.0.weight shape: torch.Size([192, 1152, 1, 1]) requires_grad: True
# 167  layer: features.6.1.block.3.1.weight shape: torch.Size([192]) requires_grad: True
# 168  layer: features.6.1.block.3.1.bias shape: torch.Size([192]) requires_grad: True
# 169  layer: features.6.2.block.0.0.weight shape: torch.Size([1152, 192, 1, 1]) requires_grad: True
# 170  layer: features.6.2.block.0.1.weight shape: torch.Size([1152]) requires_grad: True
# 171  layer: features.6.2.block.0.1.bias shape: torch.Size([1152]) requires_grad: True
# 172  layer: features.6.2.block.1.0.weight shape: torch.Size([1152, 1, 5, 5]) requires_grad: True
# 173  layer: features.6.2.block.1.1.weight shape: torch.Size([1152]) requires_grad: True
# 174  layer: features.6.2.block.1.1.bias shape: torch.Size([1152]) requires_grad: True
# 175  layer: features.6.2.block.2.fc1.weight shape: torch.Size([48, 1152, 1, 1]) requires_grad: True
# 176  layer: features.6.2.block.2.fc1.bias shape: torch.Size([48]) requires_grad: True
# 177  layer: features.6.2.block.2.fc2.weight shape: torch.Size([1152, 48, 1, 1]) requires_grad: True
# 178  layer: features.6.2.block.2.fc2.bias shape: torch.Size([1152]) requires_grad: True
# 179  layer: features.6.2.block.3.0.weight shape: torch.Size([192, 1152, 1, 1]) requires_grad: True
# 180  layer: features.6.2.block.3.1.weight shape: torch.Size([192]) requires_grad: True
# 181  layer: features.6.2.block.3.1.bias shape: torch.Size([192]) requires_grad: True
# 182  layer: features.6.3.block.0.0.weight shape: torch.Size([1152, 192, 1, 1]) requires_grad: True
# 183  layer: features.6.3.block.0.1.weight shape: torch.Size([1152]) requires_grad: True
# 184  layer: features.6.3.block.0.1.bias shape: torch.Size([1152]) requires_grad: True
# 185  layer: features.6.3.block.1.0.weight shape: torch.Size([1152, 1, 5, 5]) requires_grad: True
# 186  layer: features.6.3.block.1.1.weight shape: torch.Size([1152]) requires_grad: True
# 187  layer: features.6.3.block.1.1.bias shape: torch.Size([1152]) requires_grad: True
# 188  layer: features.6.3.block.2.fc1.weight shape: torch.Size([48, 1152, 1, 1]) requires_grad: True
# 189  layer: features.6.3.block.2.fc1.bias shape: torch.Size([48]) requires_grad: True
# 190  layer: features.6.3.block.2.fc2.weight shape: torch.Size([1152, 48, 1, 1]) requires_grad: True
# 191  layer: features.6.3.block.2.fc2.bias shape: torch.Size([1152]) requires_grad: True
# 192  layer: features.6.3.block.3.0.weight shape: torch.Size([192, 1152, 1, 1]) requires_grad: True
# 193  layer: features.6.3.block.3.1.weight shape: torch.Size([192]) requires_grad: True
# 194  layer: features.6.3.block.3.1.bias shape: torch.Size([192]) requires_grad: True
# 195  layer: features.7.0.block.0.0.weight shape: torch.Size([1152, 192, 1, 1]) requires_grad: True
# 196  layer: features.7.0.block.0.1.weight shape: torch.Size([1152]) requires_grad: True
# 197  layer: features.7.0.block.0.1.bias shape: torch.Size([1152]) requires_grad: True
# 198  layer: features.7.0.block.1.0.weight shape: torch.Size([1152, 1, 3, 3]) requires_grad: True
# 199  layer: features.7.0.block.1.1.weight shape: torch.Size([1152]) requires_grad: True
# 200  layer: features.7.0.block.1.1.bias shape: torch.Size([1152]) requires_grad: True
# 201  layer: features.7.0.block.2.fc1.weight shape: torch.Size([48, 1152, 1, 1]) requires_grad: True
# 202  layer: features.7.0.block.2.fc1.bias shape: torch.Size([48]) requires_grad: True
# 203  layer: features.7.0.block.2.fc2.weight shape: torch.Size([1152, 48, 1, 1]) requires_grad: True
# 204  layer: features.7.0.block.2.fc2.bias shape: torch.Size([1152]) requires_grad: True
# 205  layer: features.7.0.block.3.0.weight shape: torch.Size([320, 1152, 1, 1]) requires_grad: True
# 206  layer: features.7.0.block.3.1.weight shape: torch.Size([320]) requires_grad: True
# 207  layer: features.7.0.block.3.1.bias shape: torch.Size([320]) requires_grad: True
# 208  layer: features.8.0.weight shape: torch.Size([1280, 320, 1, 1]) requires_grad: True
# 209  layer: features.8.1.weight shape: torch.Size([1280]) requires_grad: True
# 210  layer: features.8.1.bias shape: torch.Size([1280]) requires_grad: True

# %%
for i, (name, params) in enumerate(cosa.named_parameters()):
    if 'features.8' in name or 'features.7' in name:
        print(f"{i}  layer: {name} shape: {params.shape} requires_grad: {params.requires_grad}")
# Out:
# 195  layer: features.7.0.block.0.0.weight shape: torch.Size([1152, 192, 1, 1]) requires_grad: True
# 196  layer: features.7.0.block.0.1.weight shape: torch.Size([1152]) requires_grad: True
# 197  layer: features.7.0.block.0.1.bias shape: torch.Size([1152]) requires_grad: True
# 198  layer: features.7.0.block.1.0.weight shape: torch.Size([1152, 1, 3, 3]) requires_grad: True
# 199  layer: features.7.0.block.1.1.weight shape: torch.Size([1152]) requires_grad: True
# 200  layer: features.7.0.block.1.1.bias shape: torch.Size([1152]) requires_grad: True
# 201  layer: features.7.0.block.2.fc1.weight shape: torch.Size([48, 1152, 1, 1]) requires_grad: True
# 202  layer: features.7.0.block.2.fc1.bias shape: torch.Size([48]) requires_grad: True
# 203  layer: features.7.0.block.2.fc2.weight shape: torch.Size([1152, 48, 1, 1]) requires_grad: True
# 204  layer: features.7.0.block.2.fc2.bias shape: torch.Size([1152]) requires_grad: True
# 205  layer: features.7.0.block.3.0.weight shape: torch.Size([320, 1152, 1, 1]) requires_grad: True
# 206  layer: features.7.0.block.3.1.weight shape: torch.Size([320]) requires_grad: True
# 207  layer: features.7.0.block.3.1.bias shape: torch.Size([320]) requires_grad: True
# 208  layer: features.8.0.weight shape: torch.Size([1280, 320, 1, 1]) requires_grad: True
# 209  layer: features.8.1.weight shape: torch.Size([1280]) requires_grad: True
# 210  layer: features.8.1.bias shape: torch.Size([1280]) requires_grad: True

# %% [markdown]
# ## The multi input model

# %%
class ContactMultiInputNetwork(nn.Module):
    def __init__(self, num_classes=1, num_features=17):
        super(ContactMultiInputNetwork, self).__init__()
        self.efficientnet = get_efficientnet_model()
        
        self.fc1 = nn.Linear(num_features, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(1536, num_classes)
        self.dropout = nn.Dropout(p=0.2)
        
        self.bn1 = nn.BatchNorm1d(512)
        self.bn2 = nn.BatchNorm1d(256)
        
    def forward(self, x):
        # x[0] contains the image tensor and x[1] the feature vector tensor
        img_feature = self.efficientnet(x[0])
        # shape = (batch_size, 1280)
        x = F.relu(self.bn1(self.fc1(x[1])))
        x = F.relu(self.bn2(self.dropout(self.fc2(x))))
        # shape = (batch_size, 256)
        # concatenate image and vector features
        x = torch.cat([img_feature, x], dim=1)
        # shape = (batch_size, 1536)
        # final classification
        x = self.fc3(x)
        # shape = (batch_size, 1)
        
        return x

# %%
# 1 class for binary output
# feature vector has size 8
model = ContactMultiInputNetwork(num_classes=1, num_features=17)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Training Utils

# %%
class Averager():
    """
    An Averager keeps track of the training and validation loss values
    and helps to get the average for each epoch as well
    """
    def __init__(self):
        self.current_total = 0.0
        self.iterations = 0.0

    def send(self, value):
        self.current_total += value
        self.iterations += 1

    @property
    def value(self):
        if self.iterations == 0:
            return 0
        else:
            return 1.0 * self.current_total / self.iterations

    def reset(self):
        self.current_total = 0.0
        self.iterations = 0.0

# %%
def save_loss_plot(output_dir, mean_train_loss, mean_valid_loss, epoch_num, model_name):
    """
    Save plots with the loss curves of the model training
    """
    fig, ax = plt.subplots(figsize=(15,10))

    ax.plot(np.arange(epoch_num)+1, mean_train_loss, label='Training loss')
    ax.plot(np.arange(epoch_num)+1, mean_valid_loss, label='Validation Loss')
    
    ax.set_xticks(np.arange(1, epoch_num+1, step=1))
    if (epoch_num > 20):
        ax.set_xticks(np.arange(0, epoch_num+1, step=2))
    if(epoch_num > 50):
        ax.set_xticks(np.arange(0, epoch_num+1, step=5))
    if(epoch_num > 100):
        ax.set_xticks(np.arange(0, epoch_num+1, step=10))
    if(epoch_num > 1000):
        ax.set_xticks(np.arange(0, epoch_num+1, step=100))
        
    ax.set_ylabel('Loss')
    ax.set_xlabel('Epochs')
    ax.set_title('Loss Curves')
    ax.legend()
    fig.savefig(f"{output_dir}/{model_name}_epoch_loss.png")

    print('SAVING PLOTS COMPLETE...')

    plt.close('all')

# %%
def save_model(epoch, model, optimizer, model_name='model', out_dir='.'):
    """
    Function to save the trained model
    """
    torch.save({
                'epoch': epoch+1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                }, f'{out_dir}/{model_name}.pth')

    
class SaveBestModel:
    """
    Class to save the best model while training. If the current epoch's 
    validation loss is less than the previous least less, then save the
    model state.
    """
    def __init__(
        self, best_valid_loss=float('inf'), model_name='model'
    ):
        self.best_valid_loss = best_valid_loss
        self.non_improve_iters = 0
        self.model_name = model_name
        
    def __call__(
        self, current_valid_loss, 
        epoch, model, optimizer, out_dir='.'
    ):
        if current_valid_loss < self.best_valid_loss:
            self.non_improve_iters = 0
            self.best_valid_loss = current_valid_loss
            print(f"\nBest validation loss: {self.best_valid_loss}")
            print(f"\nSaving best model for epoch: {epoch+1}\n")
            model_name = f'bm_{self.model_name}_epoch_{epoch+1}'
            save_model(epoch, model, optimizer, model_name, out_dir)
        else:
            self.non_improve_iters += 1

# %% [markdown]
# ### Training 1 epoch

# %%
def train_one_epoch(model, data_loader, criterion, optimizer, device, train_loss_averager):
    """
    Function that trains the given model for one epoch 
    with the given data loader
    """
    # activate model training mode in case its in evaluation mode
    model.train()
    # initialize tqdm progress bar
    prog_bar = tqdm(data_loader, total=len(data_loader))
    for i, (img_data, feature_data, labels) in enumerate(prog_bar):
        # send data to device
        img_data = img_data.to(device)
        feature_data = feature_data.to(device)
        labels = labels.to(device).to(torch.float32)
        # reset the gradient accummulation from the previous batch
        optimizer.zero_grad()
        # make a prediction with the model
        prediction = model([img_data, feature_data]).to(torch.float32).squeeze(dim=1)
        # compute the loss 
        loss = criterion(prediction, labels)
        # save loss values to the averaher
        train_loss_averager.send(loss.item())
        # backpropagate the loss gradient
        loss.backward()
        # uptade parameters
        optimizer.step()

        # print the mean batch loss at each iteration
        prog_bar.set_description(desc=f"Training Loss: {train_loss_averager.value:.4f}")

# %% [markdown]
# ### Validate Function

# %%
def validate_model(model, data_loader, criterion, device, val_loss_averager):
    """
    Uses the model on all the data from the data loader and 
    returns the predictions and the true targets. It also updates
    the loss averager
    """
    # initialize tqdm progress bar
    prog_bar = tqdm(data_loader, total=len(data_loader))
    loss_list = np.array([])
    total_predictions = torch.tensor([]).to(device)
    total_target_labels = torch.tensor([]).to(device)
    
    for i, (img_data, feature_data, labels) in enumerate(prog_bar):
        # send data to device
        img_data = img_data.to(device)
        feature_data = feature_data.to(device)
        labels = labels.to(device).to(torch.float32)
        # make a prediction with the model in evaluation mode
        with torch.no_grad():
            # activate evaluation mode for batchnorm layers
            model.eval()
            prediction = model([img_data, feature_data]).to(torch.float32).squeeze(dim=1)

        # add batch predictions and true labels to total lists
        total_predictions = torch.cat((total_predictions, prediction), dim=0)    
        total_target_labels = torch.cat((total_target_labels, labels), dim=0)    
        # compute the loss 
        loss = criterion(prediction, labels)
        # update loss averager
        val_loss_averager.send(loss.item())
        
        # print the mean batch loss at each iteration
        prog_bar.set_description(desc=f"Validation Loss: {val_loss_averager.value:.4f}")

    # return total predictions and total true_labels
    return total_predictions, total_target_labels

# %%
def get_pos_weight(train_df):
    """
    Returns a positive class weight equal to n_negative_contact / n_positive contact
    this way, the positive contacts will have more weight in the loss function
    """
    num_pos_contacts = train_df['contact_truth'].sum()
    num_neg_contacts = len(train_df) - num_pos_contacts
    pos_weight = torch.tensor([num_neg_contacts / num_pos_contacts])
    
    return pos_weight

# %% [markdown]
# ### Constants

# %%
CLASSES = ['0', '1']
# detect the device (GPU or CPU)
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# set the number of epochs
EPOCHS = 100
# set the learning rate
LR = 0.001
# maximum iterations with no validation set improvement until early stoping
EARLY_STOP= 5

MODEL_NAME = 'multi_efficientnet_CLS_p2p_v2'
MODEL_DIR = 'trained_models'
PLOT_DIR = 'training_plots'

# !mkdir {MODEL_DIR}
# !mkdir {PLOT_DIR}
# Out:
# A subdirectory or file trained_models already exists.
# A subdirectory or file training_plots already exists.

# %% [markdown]
# ### Main training loop

# %%
# TRAINING PARAMS
# initialize model and send to device
model = ContactMultiInputNetwork(num_classes=1, num_features=17)  # 1 output for binary prediction
model = model.to(DEVICE)
# initialize Adam optimizer with default parameters (like the paper)
# optimizer = Adam(model.parameters(), lr=LR)
optimizer = torch.optim.SGD(model.parameters(), LR, momentum=0.9, weight_decay=1e-6)
# so it halves the learning rate every 5 epochs
scheduler = lr_scheduler.LinearLR(optimizer, start_factor=1, end_factor=0, total_iters=EPOCHS)
# initialize loss function (sigmoid + binary cross entropy)
# set a positive class weight equal to n_negative_contact / n_positive contact
# this way, the positive contacts will have more weight in the loss function
pos_weight = get_pos_weight(train_df).to(DEVICE)
criterion = nn.BCEWithLogitsLoss(pos_weight = pos_weight)

# initialize the loss Averager class
train_loss_hist = Averager()
val_loss_hist = Averager()
# initialize SaveBestModel class
save_best_model = SaveBestModel(model_name=MODEL_NAME)
# mean losses for train and validation at every epoch
mean_train_losses = []
mean_validation_losses = []

# epoch loop
for epoch in range(EPOCHS):
    print(f"Starting epoch {epoch+1}")
    # reset the training and valitation loss histories for the current epoch
    train_loss_hist.reset()
    val_loss_hist.reset()

    # start timer and carry out training and evaluation
    start = time.time()
    # train one epoch
    train_one_epoch(model, loader_train, criterion, optimizer, 
                    DEVICE, train_loss_hist)
    # update the lr scheduler
    scheduler.step()
    #evaluate the model
    y_pred, y_true = validate_model(model, loader_test, criterion,
                                    DEVICE, val_loss_hist)
    
    print(f"Epoch #{epoch+1} train_loss: {train_loss_hist.value:.3f}")
    print(f"Epoch #{epoch+1} validation_loss: {val_loss_hist.value:.3f}")
    end = time.time()
    print(f"Took {(end - start):.3f} seconds for epoch {epoch+1}")

    # save the mean train and validation losses of this epoch
    mean_train_losses.append(train_loss_hist.value)
    mean_validation_losses.append(val_loss_hist.value)

    # save the best model until now if we have the minimum val loss this epoch
    save_best_model(val_loss_hist.value, epoch, model, optimizer, 
                    out_dir=MODEL_DIR)
    
    #save the current epoch model
    save_model(epoch, model, optimizer, model_name=MODEL_NAME,
               out_dir=MODEL_DIR)

    #save the loss plot
    save_loss_plot('training_plots', mean_train_losses, mean_validation_losses, 
                   epoch+1, MODEL_NAME)
    print('\n')

print('Training done')
# Out:
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Starting epoch 1
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #1 train_loss: 0.884
# Epoch #1 validation_loss: 0.792
# Took 2068.956 seconds for epoch 1
#
# Best validation loss: 0.7916996800168012
#
# Saving best model for epoch: 1
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 2
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #2 train_loss: 0.813
# Epoch #2 validation_loss: 0.759
# Took 2066.971 seconds for epoch 2
#
# Best validation loss: 0.7590236238185731
#
# Saving best model for epoch: 2
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 3
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #3 train_loss: 0.787
# Epoch #3 validation_loss: 0.738
# Took 2045.181 seconds for epoch 3
#
# Best validation loss: 0.7377032504359854
#
# Saving best model for epoch: 3
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 4
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #4 train_loss: 0.764
# Epoch #4 validation_loss: 0.739
# Took 2043.406 seconds for epoch 4
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 5
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #5 train_loss: 0.747
# Epoch #5 validation_loss: 0.709
# Took 2099.860 seconds for epoch 5
#
# Best validation loss: 0.7089734349151118
#
# Saving best model for epoch: 5
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 6
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #6 train_loss: 0.734
# Epoch #6 validation_loss: 0.713
# Took 2025.135 seconds for epoch 6
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 7
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #7 train_loss: 0.721
# Epoch #7 validation_loss: 0.709
# Took 2019.761 seconds for epoch 7
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 8
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #8 train_loss: 0.703
# Epoch #8 validation_loss: 0.678
# Took 2045.625 seconds for epoch 8
#
# Best validation loss: 0.6777027363179908
#
# Saving best model for epoch: 8
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 9
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #9 train_loss: 0.693
# Epoch #9 validation_loss: 0.663
# Took 2051.326 seconds for epoch 9
#
# Best validation loss: 0.6630700749275416
#
# Saving best model for epoch: 9
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 10
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #10 train_loss: 0.677
# Epoch #10 validation_loss: 0.719
# Took 2043.220 seconds for epoch 10
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 11
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #11 train_loss: 0.663
# Epoch #11 validation_loss: 0.657
# Took 2041.335 seconds for epoch 11
#
# Best validation loss: 0.6566690760372622
#
# Saving best model for epoch: 11
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 12
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #12 train_loss: 0.647
# Epoch #12 validation_loss: 0.640
# Took 2046.687 seconds for epoch 12
#
# Best validation loss: 0.640238066299976
#
# Saving best model for epoch: 12
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 13
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #13 train_loss: 0.632
# Epoch #13 validation_loss: 0.825
# Took 2035.788 seconds for epoch 13
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 14
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #14 train_loss: 0.616
# Epoch #14 validation_loss: 0.649
# Took 2042.742 seconds for epoch 14
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 15
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #15 train_loss: 0.604
# Epoch #15 validation_loss: 0.612
# Took 2044.870 seconds for epoch 15
#
# Best validation loss: 0.6115849705780991
#
# Saving best model for epoch: 15
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 16
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #16 train_loss: 0.590
# Epoch #16 validation_loss: 0.795
# Took 2039.023 seconds for epoch 16
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 17
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #17 train_loss: 0.579
# Epoch #17 validation_loss: 0.723
# Took 2038.312 seconds for epoch 17
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 18
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #18 train_loss: 0.564
# Epoch #18 validation_loss: 0.578
# Took 2085.866 seconds for epoch 18
#
# Best validation loss: 0.5779098977742368
#
# Saving best model for epoch: 18
#
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 19
#   0%|          | 0/5931 [00:00<?, ?it/s]
#   0%|          | 0/1483 [00:00<?, ?it/s]
# Epoch #19 train_loss: 0.552
# Epoch #19 validation_loss: 0.757
# Took 2115.980 seconds for epoch 19
# SAVING PLOTS COMPLETE...
#
#
# Starting epoch 20
#   0%|          | 0/5931 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22580\2201185959.py in <module>
#      34     # train one epoch
#      35     train_one_epoch(model, loader_train, criterion, optimizer,
# ---> 36                     DEVICE, train_loss_hist)
#      37     # update the lr scheduler
#      38     scheduler.step()
#
# ~\AppData\Local\Temp\ipykernel_22580\1102689709.py in train_one_epoch(model, data_loader, criterion, optimizer, device, train_loss_averager)
#      16         optimizer.zero_grad()
#      17         # make a prediction with the model
# ---> 18         prediction = model([img_data, feature_data]).to(torch.float32).squeeze(dim=1)
#      19         # compute the loss
#      20         loss = criterion(prediction, labels)
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Temp\ipykernel_22580\2029534820.py in forward(self, x)
#      14     def forward(self, x):
#      15         # x[0] contains the image tensor and x[1] the feature vector tensor
# ---> 16         img_feature = self.efficientnet(x[0])
#      17         # shape = (batch_size, 1280)
#      18         x = F.relu(self.bn1(self.fc1(x[1])))
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.conda\envs\contact\lib\site-packages\torchvision\models\efficientnet.py in forward(self, x)
#     353
#     354     def forward(self, x: Tensor) -> Tensor:
# --> 355         return self._forward_impl(x)
#     356
#     357
#
# ~\.conda\envs\contact\lib\site-packages\torchvision\models\efficientnet.py in _forward_impl(self, x)
#     343
#     344     def _forward_impl(self, x: Tensor) -> Tensor:
# --> 345         x = self.features(x)
#     346
#     347         x = self.avgpool(x)
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# ~\.conda\envs\contact\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     458                             _pair(0), self.dilation, self.groups)
#     459         return F.conv2d(input, weight, bias, self.stride,
# --> 460                         self.padding, self.dilation, self.groups)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
print(f"Best valid loss: {save_best_model.best_valid_loss:.5f}")
Image.open(f'{PLOT_DIR}/{MODEL_NAME}_epoch_loss.png')
# Out:
# Best valid loss: 0.48775
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x1000>

# %% [markdown]
# ## Check Predictions

# %% [markdown]
# ### Load model

# %%
def load_model(model_path, num_classes, device, num_features):
    """
    Returns a efficientnet model with the weights from the saved model
    """
    model = ContactMultiInputNetwork(num_classes=1, num_features=num_features)
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device).eval();
    
    return model

# %%
#load the best model on the validation set
best_model_path = os.path.join(MODEL_DIR, 'bm_multi_efficientnet_CLS_p2p_v1_epoch_12.pth')
best_model = load_model(best_model_path, 1, DEVICE, num_features=17)

# %%
# save full model
# torch.save(best_model, os.path.join(MODEL_DIR, 'bm_multi_efficientnet_CLS_ground_v1_epoch_14.pt'))

# %% [markdown]
# ### Check validation set

# %%
val_loss_hist = Averager()
pos_weight = get_pos_weight(train_df).to(DEVICE)
criterion = nn.BCEWithLogitsLoss(pos_weight = pos_weight)
y_pred, y_true = validate_model(best_model, loader_test, criterion,
                                    DEVICE, val_loss_hist)
# Out:
#   0%|          | 0/1483 [00:00<?, ?it/s]

# %% [markdown]
# ### Mathews correlation coefficient

# %%
# mathews correlation coefficient

thresholds = np.arange(0.0, 0.5, 0.01)
best_score = 0
best_thrs = -1
for thrs in thresholds:
    y_pred_clean = (torch.sigmoid(y_pred) > thrs).double()
    score = matthews_corrcoef(y_pred_clean.cpu(), y_true.cpu())
    if score > best_score:
        best_score = score
        best_thrs = thrs

y_pred_clean = (torch.sigmoid(y_pred) > best_thrs).double()
print(f"Best acc threshold: {best_thrs}")
print(f"Matheys corr coef: {best_score:.5f}")
# Out:
# Best acc threshold: 0.49
# Matheys corr coef: 0.65720

# %%
# naive score
matthews_corrcoef((test_df['p2p_distance'] < 1.1).astype(int), test_df['contact_truth'].values)
# Out:
# 0.506317943915968

# %% [markdown]
# ### Confusion Matrix

# %%
def show_confusion_matrix(y_pred, y_true, display_labels, title='Confusion Matrix'):
    conf_matrix = confusion_matrix(y_true, y_pred)
    conf_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,
                                        display_labels=display_labels)

    fig, ax = plt.subplots(figsize=(15,15))
    plt.title(title)
    conf_display.plot(cmap=plt.cm.Blues, ax=ax);
    return conf_matrix

# %%
conf_matrix = show_confusion_matrix(y_pred_clean.cpu(), y_true.cpu(), CLASSES)

# %% [markdown]
# ## Validate on whole dataset (ground)

# %%
# merge contact_df and contact_image_df
full_train_df = train_contact_df_reduced.merge(contact_image_endzone_df, 
                                 left_on=['contact_id'], 
                                 right_on=['contact_id'], 
                                 how='left').drop_duplicates()
# use only the rows where the crop was generated
full_train_df = full_train_df[full_train_df['crop_generated'] == True]
# get the ground contacts
full_train_df = full_train_df[full_train_df['nfl_player_id_2'] != -1]


full_train_df
# Out:
#                      contact_id     game_play  step  nfl_player_id_1  \
# 12       58168_003392_0_38590_G  58168_003392     0            38590
# 13       58168_003392_0_43854_G  58168_003392     0            43854
# 14       58168_003392_0_41257_G  58168_003392     0            41257
# 15       58168_003392_0_41944_G  58168_003392     0            41944
# 16       58168_003392_0_42386_G  58168_003392     0            42386
# ...                         ...           ...   ...              ...
# 660529  58582_003121_91_52493_G  58582_003121    91            52493
# 660531  58582_003121_91_45287_G  58582_003121    91            45287
# 660532  58582_003121_91_46105_G  58582_003121    91            46105
# 660535  58582_003121_91_52500_G  58582_003121    91            52500
# 660539  58582_003121_91_47872_G  58582_003121    91            47872
#
#         nfl_player_id_2  game_key  play_id                          datetime  \
# 12                   -1     58168     3392  2020-09-11 03:01:48.100000+00:00
# 13                   -1     58168     3392  2020-09-11 03:01:48.100000+00:00
# 14                   -1     58168     3392  2020-09-11 03:01:48.100000+00:00
# 15                   -1     58168     3392  2020-09-11 03:01:48.100000+00:00
# 16                   -1     58168     3392  2020-09-11 03:01:48.100000+00:00
# ...                 ...       ...      ...                               ...
# 660529               -1     58582     3121  2021-10-12 02:42:29.100000+00:00
# 660531               -1     58582     3121  2021-10-12 02:42:29.100000+00:00
# 660532               -1     58582     3121  2021-10-12 02:42:29.100000+00:00
# 660535               -1     58582     3121  2021-10-12 02:42:29.100000+00:00
# 660539               -1     58582     3121  2021-10-12 02:42:29.100000+00:00
#
#        team_1 position_1  ...  orientation_2  acceleration_2  sa_2  \
# 12       home          G  ...            0.0             0.0   0.0
# 13       away        OLB  ...            0.0             0.0   0.0
# 14       away         CB  ...            0.0             0.0   0.0
# 15       away         DT  ...            0.0             0.0   0.0
# 16       away        ILB  ...            0.0             0.0   0.0
# ...       ...        ...  ...            ...             ...   ...
# 660529   away         FS  ...            0.0             0.0   0.0
# 660531   away         CB  ...            0.0             0.0   0.0
# 660532   away        MLB  ...            0.0             0.0   0.0
# 660535   home         WR  ...            0.0             0.0   0.0
# 660539   away        MLB  ...            0.0             0.0   0.0
#
#         p2p_distance  contact_truth  contact  crop_generated  rewinded_frames  \
# 12             999.0              0        0            True              0.0
# 13             999.0              0        0            True              0.0
# 14             999.0              0        0            True              0.0
# 15             999.0              0        0            True              0.0
# 16             999.0              0        0            True              0.0
# ...              ...            ...      ...             ...              ...
# 660529         999.0              0        0            True             10.0
# 660531         999.0              0        0            True             10.0
# 660532         999.0              0        0            True             60.0
# 660535         999.0              0        0            True             10.0
# 660539         999.0              0        0            True             10.0
#
#         miss_helmet_dets miss_player_dets
# 12                   0.0              0.0
# 13                   0.0              0.0
# 14                   0.0              0.0
# 15                   0.0              0.0
# 16                   0.0              0.0
# ...                  ...              ...
# 660529               0.0              0.0
# 660531               0.0              0.0
# 660532               0.0              1.0
# 660535               0.0              0.0
# 660539               0.0              0.0
#
# [325212 rows x 37 columns]

# %%
# dataset and loader
# train
p_g_contact_dataset_full = PlayerContactDataset(DATA_PATH, full_train_df, 'Endzone', image_transform_test)

loader_full = DataLoader(p_g_contact_dataset_full,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=0,
                         drop_last=True)

# %%
# load model
best_model_path = os.path.join(MODEL_DIR, 'bm_efficientnet_CLS_ground_v6_epoch_8.pth')
best_model = load_model(best_model_path, 1, DEVICE)
# Out:
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\AT016638\.conda\envs\contact\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# inference on full dataset
val_loss_hist = Averager()
criterion = nn.BCEWithLogitsLoss()
y_pred, y_true = validate_model(best_model, loader_full, criterion,
                                    DEVICE, val_loss_hist)
# Out:
#   0%|          | 0/10162 [00:00<?, ?it/s]

# %%
# mathews correlation coefficient

thresholds = np.arange(0.0, 0.5, 0.01)
best_score = 0
best_thrs = -1
for thrs in thresholds:
    y_pred_clean = (torch.sigmoid(y_pred) > thrs).double()
    score = matthews_corrcoef(y_pred_clean.cpu(), y_true.cpu())
    if score > best_score:
        best_score = score
        best_thrs = thrs

y_pred_clean = (torch.sigmoid(y_pred) > best_thrs).double()
print(f"Best acc threshold: {best_thrs}")
print(f"Matheys corr coef: {best_score:.5f}")
# Out:
# Best acc threshold: 0.49
# Matheys corr coef: 0.49589

# %%
conf_matrix = show_confusion_matrix(y_pred_clean.cpu(), y_true.cpu(), CLASSES)
